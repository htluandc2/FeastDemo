# %%
import pandas as pd
import feast

# %%
load_df = pd.read_parquet('credit_scoring/feature_repo/raw_data/loan_table.parquet')
load_df
# Out:
#        loan_id        dob_ssn  zipcode  person_age  person_income  \
# 0        10000  19530219_5179    76104          22          59000
# 1        10001  19520816_8737    70380          21           9600
# 2        10002  19860413_2537    97039          25           9600
# 3        10003  19760701_8090    63785          23          65500
# 4        10004  19830125_8297    82223          24          54400
# ...        ...            ...      ...         ...            ...
# 28633    38633  19491126_1487    43205          57          53000
# 28634    38634  19681208_6537    24872          54         120000
# 28635    38635  19880422_2592    68826          65          76000
# 28636    38636  19901017_6108    92014          56         150000
# 28637    38637  19960703_3449    69033          66          42000
#
#       person_home_ownership  person_emp_length      loan_intent  loan_amnt  \
# 0                      RENT              123.0         PERSONAL      35000
# ...

# %%
fs = feast.FeatureStore(repo_path='credit_scoring/feature_repo/')
feature_service_v1 = fs.get_feature_service("features_group_v1")
feature_service_v2 = fs.get_feature_service("features_group_v2")

# %%
training_df = fs.get_historical_features(
    entity_df=load_df,
    features=feature_service_v1
).to_df()
training_df2= fs.get_historical_features(
    entity_df=load_df,
    features=feature_service_v2
).to_df()

# %%
training_df
# Out:
#        loan_id        dob_ssn  zipcode  person_age  person_income  \
# 0        38637  19960703_3449    69033          66          42000
# 1        38276  19770128_3701    61345          39          75000
# 2        38287  19600201_7821    54901          48         140000
# 3        38286  19921119_7451    20912          36          58000
# 4        38285  19580615_7535    64856          46          48956
# ...        ...            ...      ...         ...            ...
# 28633    10041  20000903_5182    60191          26         300000
# 28634    10153  19610414_1854    81008          25          61959
# 28635    10018  19751208_7623    20692          23         113000
# 28636    10188  19711230_6002    13602          24          75000
# 28637    10228  19760923_8246    33885          23          66215
#
#       person_home_ownership  person_emp_length        loan_intent  loan_amnt  \
# 0                      RENT                2.0            MEDICAL       6475
# ...

# %%
training_df2
# Out:
#        loan_id        dob_ssn  zipcode  person_age  person_income  \
# 0        38637  19960703_3449    69033          66          42000
# 1        38276  19770128_3701    61345          39          75000
# 2        38287  19600201_7821    54901          48         140000
# 3        38286  19921119_7451    20912          36          58000
# 4        38285  19580615_7535    64856          46          48956
# ...        ...            ...      ...         ...            ...
# 28633    10041  20000903_5182    60191          26         300000
# 28634    10153  19610414_1854    81008          25          61959
# 28635    10018  19751208_7623    20692          23         113000
# 28636    10188  19711230_6002    13602          24          75000
# 28637    10228  19760923_8246    33885          23          66215
#
#       person_home_ownership  person_emp_length        loan_intent  loan_amnt  \
# 0                      RENT                2.0            MEDICAL       6475
# ...
